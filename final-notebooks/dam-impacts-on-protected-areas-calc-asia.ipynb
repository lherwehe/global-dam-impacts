# %% [markdown]
# ## Asia
# This notebook contains functions that combine World Database of Protected Areas and Ramsar data for a country or continent to create a full protected areas dataset for the desired region and calculates the total length of rivers on protected lands and total area of protected lands that are affected by proposed dams by country for a desired continent.

# %%
# Clip WDPA_Asia_polys to fit map

# Imports
import warnings
import os
import sys

import numpy as np
import numpy.ma as ma
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

import seaborn as sns

from geopandas import GeoDataFrame as gdf
from geopandas import GeoSeries as gs
from shapely.geometry import Point, Polygon

import earthpy as et
import earthpy.plot as ep
import contextily as ctx

# %%
# Check path and set working directory.
wd_path = os.path.join(et.io.HOME, 'earth-analytics', 'data')
if os.path.exists(wd_path):
    os.chdir(wd_path)
else:
    print("Path does not exist")

# %%
# Download Data stored on figshare
# Free flowing rivers current DOR
et.data.get_data(url="https://ndownloader.figshare.com/files/23273213")

# Free flowing rivers future DOR
et.data.get_data(url="https://ndownloader.figshare.com/files/23273216")

# World Database of Protected Areas Africa
et.data.get_data(url="https://ndownloader.figshare.com/files/23354894")

# World Database of Protected Areas Asia
et.data.get_data(url="https://ndownloader.figshare.com/files/23354900")

# World Database of Protected Areas South America
et.data.get_data(url="https://ndownloader.figshare.com/files/23355335")

# World Database of Protected Areas Europe
# et.data.get_data(url="https://ndownloader.figshare.com/files/23355098")

# World Database of Protected Areas North America
# et.data.get_data(url="https://ndownloader.figshare.com/files/23355317")

# Ramsar Sites
et.data.get_data(url="https://ndownloader.figshare.com/files/22507082")

# Country boundaries
et.data.get_data(url="https://ndownloader.figshare.com/files/22507058")

# Continent boundaries
et.data.get_data(url="https://ndownloader.figshare.com/files/23392280")

# Continent-country csv
et.data.get_data(url="https://ndownloader.figshare.com/files/23393756")
# Out:
# 'C:\\Users\\lherwehe\\earth-analytics\\data\\earthpy-downloads\\continent-country.csv'

# %%
# Custon Function
def all_pa_continent(wdpa_polys, ramsar_polys, cont_name):
    """ This function takes WDPA polygons for a continent and global ramsar polygons and returns a multipolygon feature 
    of the World Database of Protected Areas merged with the ramsar areas for that continent.

    Parameters
    ----------
    wdpa_polys: gdf
        The feature with the WDPA polygons for the selected continent.
    ramsar_polys: gdf
        The feature with all global ramsar polygons.
    cont_name: str
        The name of the selected continent.

    Returns
    -------
    wdpa_ramsar: gdf
        A gdf of both the ramsar and WDPA protected areas for the continent.
    """
    # Remove ramsar areas from WDPA dataset
    try:
        wdpa_polys.set_index('DESIG', inplace=True)
        wdpa_polys.drop(
            "Ramsar Site, Wetland of International Importance", inplace=True)
    except:
        print('No ramsar areas in WDPA dataset.')

    # Remove duplicates from WDPA dataset (areas tagged by both state and local authorities)
    try:
        wdpa_polys.set_index('NAME', inplace=True)
        wdpa_polys.drop_duplicates(subset=None,
                                   keep='first', inplace=False)
    except:
        print('No duplicates in the WDPA dataset.')

    # Pull out the ramsar areas for the continent or country and merge with protected areas
    ramsar_polys = ramsar_polys[ramsar_polys["continent"] == cont_name]
    wdpa_ramsar = wdpa_polys.append(ramsar_polys, 'sort=True')

    return wdpa_ramsar

# %%
# function to get unique values
def unique(list1):
 
    # intilize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print(x)
    return unique_list

# %%
# Open continent & country borders & ISOs
country_borders = gpd.read_file(os.path.join(wd_path, "earthpy-downloads", "country-borders",
                                             "99bfd9e7-bb42-4728-87b5-07f8c8ac631c2020328-1-1vef4ev.lu5nk.shp"))

continent_iso = pd.read_csv(os.path.join(wd_path, "earthpy-downloads",
                                         "continent-country.csv"))

continent_borders = gpd.read_file(os.path.join(wd_path, "earthpy-downloads", "continent-poly",
                                               "Continents.shp"))

# Reproject data to World Equidistant Cylindrical, datum WGS84, units meters, EPSG 4087
country_borders = country_borders.to_crs('epsg:4087')
continent_borders = continent_borders.to_crs('epsg:4087')
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
# Open the dams csv files with pandas
fname = os.path.join("earthpy-downloads", "future_dams_2015.csv")
df = pd.read_csv(fname)

# Covert the pandas dataframe to a shapefile for plotting
# Set output path for shp
dams_path = os.path.join('earthpy-downloads')
if not os.path.exists(dams_path):
    os.mkdir(dams_path)

# Define the geometry for the points
geometry = [Point(xy) for xy in zip(df.Lon_Cleaned, df.LAT_cleaned)]
crs = {'init': 'epsg:4326'}
geo_df = gdf(df, crs=crs, geometry=geometry)
geo_df.to_file(driver='ESRI Shapefile', filename=os.path.join(
    dams_path, 'proposed_dams.shp'))

# Open the proposed dams shapefile with geopandas
dams_all = gpd.read_file(os.path.join(dams_path, "proposed_dams.shp"))

# %%
# Open ramsar areas
ramsar_polys = gpd.read_file(os.path.join(
    "earthpy-downloads", "ramsar-site-data", "ramsar-boundaries",
    "features_publishedPolygon.shp"))

# Rename ramsar columns to match WDPA
try:
    ramsar_polys = ramsar_polys.rename(
        columns={"iso3": "PARENT_ISO", "officialna": "NAME", "area_off": "Shape_Area"})
except:
    print('Ramsar column names already match WDPA dataset.')

# Merge continent names with ramsar data for analyzing by continent
ramsar_polys = pd.merge(ramsar_polys, continent_iso,
                        left_on='PARENT_ISO', right_on='ISO3')

# Data cleaning - take only necessary ramsar columns
ramsar_polys = ramsar_polys[['NAME', 'PARENT_ISO',
                             'Shape_Area', 'continent', 'geometry']]

# Reproject ramsar data to  World Equidistant Cylindrical, datum WGS84, units meters, EPSG 4087
ramsar_polys = ramsar_polys.to_crs('epsg:4087')
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
# Open current DOR shapefiles
dor_0to5 = gpd.read_file(os.path.join(wd_path,
                                      "earthpy-downloads", "DOR_Binned", "DOR_0to5.shp"))
dor_5to10 = gpd.read_file(os.path.join(wd_path,
                                       "earthpy-downloads", "DOR_Binned", "DOR_5to10.shp"))
dor_10to15 = gpd.read_file(os.path.join(wd_path,
                                        "earthpy-downloads", "DOR_Binned", "DOR_10to15.shp"))
dor_15to20 = gpd.read_file(os.path.join(wd_path,
                                        "earthpy-downloads", "DOR_Binned", "DOR_15to20.shp"))
dor_over20 = gpd.read_file(os.path.join(wd_path,
                                        "earthpy-downloads", "DOR_Binned", "DOR_over20.shp"))

# %%
# Get all current rivers in selected continent
all_rivers_0to5_asia = dor_0to5[dor_0to5['CONTINENT'] == "Asia"]
all_rivers_5to10_asia = dor_5to10[dor_5to10['CONTINENT'] == "Asia"]
all_rivers_10to15_asia = dor_10to15[dor_10to15['CONTINENT'] == "Asia"]
all_rivers_15to20_asia = dor_15to20[dor_15to20['CONTINENT'] == "Asia"]
all_rivers_over20_asia = dor_over20[dor_over20['CONTINENT'] == "Asia"]

# %%
# For loop to (1) calculating difference in DOR between planned and current, (2) pulling only rivers with class > 3,
# (3) projecting rivers, (4) buffer by 1/100 km to become polys for overlay fuction, (5) pull only needed columns

gdf_list = [all_rivers_0to5_asia, all_rivers_5to10_asia,
            all_rivers_10to15_asia, all_rivers_15to20_asia, all_rivers_over20_asia]
river_list_prj = []

for shp in gdf_list:
    shp['DOR_DIFF'] = shp['DOR_PLA'] - shp['DOR']
    shp = shp[shp.RIV_CLASS >= 3]
    shp = shp.to_crs('epsg:4087')
    shp['geometry'] = shp.buffer(100)
    shp = shp[['LENGTH_KM', 'RIV_ORD', 'RIV_CLASS', 'CONTINENT',
               'ISO_NAME', 'BAS_NAME', 'DOR', 'DOR_PLA', 'DOR_DIFF', 'Shape_Leng', 'geometry']]
    river_list_prj.append(shp)

# Re-assign names based on list index
dor_0to5 = river_list_prj[0]
dor_5to10 = river_list_prj[1]
dor_10to15 = river_list_prj[2]
dor_15to20 = river_list_prj[3]
dor_over20 = river_list_prj[4]

# Concatanate all rivers gdfs for easier analysis later
all_rivers = pd.concat([dor_0to5, dor_5to10, dor_10to15,
                        dor_15to20, dor_over20], axis=0)

# Remove rivers that have DOR_DIFF of 0
all_rivers_lg = all_rivers[all_rivers.DOR_DIFF > 0]
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
# Analyze Asia
wdpa_asia_polys = gpd.read_file(os.path.join(wd_path,
                                             "earthpy-downloads", "WDPA_Asia", "WDPA_Asia.shp"))

# Data cleaning - remove polygons with no area & take only the needed columns from WDPA dataset
wdpa_asia_polys = wdpa_asia_polys[wdpa_asia_polys.geometry != None]

# Merge continent asiames with WDPA data for aasialyzing by continent
wdpa_asia_polys = pd.merge(wdpa_asia_polys, continent_iso,
                           left_on='PARENT_ISO', right_on='ISO3')

# Take only the columns we need
wdpa_asia_polys = wdpa_asia_polys[[
    'NAME', 'DESIG', 'PARENT_ISO', 'Shape_Area', 'continent', 'geometry']]

# Reporject WDPA data
wdpa_asia_polys = wdpa_asia_polys.to_crs('epsg:4087')

# Get the combined WDPA & ramsar areas for selected continent
wdpa_ramsar_asia = all_pa_continent(wdpa_asia_polys, ramsar_polys, "Asia")

# Getting river length affected
# Overlay current rivers on protected areas for selected continent to get ONLY rivers the overlap PAs
river_overlap_asia = gpd.overlay(
    wdpa_ramsar_asia, all_rivers_lg, how='intersection')

# Getting protected areas affected
# Overlay projected rivers on pas for selected continent to get ONLY pas that overlap rivers
pa_overlap_asia = gpd.overlay(
    river_overlap_asia, wdpa_ramsar_asia, how='intersection')

# Get a list of countries in each continent for calculating lengths/areas by country later
asia_countries = continent_iso[continent_iso.continent == 'Asia']

# Create empty lists
country_sums = []
area_sums = []
countries = []

# Sum up the total river length affected by country in the continent
for country in asia_countries.ISO3:
    country_sums.append((
        river_overlap_asia.loc[river_overlap_asia['PARENT_ISO'] == country, 'LENGTH_KM'].sum()).round(0))
    area_sums.append((
        pa_overlap_asia.loc[pa_overlap_asia['PARENT_ISO_1'] == country, 'Shape_Area_1'].sum()).round(0))
    countries.append(country)

 # Create a pandas dataframe of lengths and areas affected
asia_output = pd.DataFrame(list(zip(countries, country_sums, area_sums)), columns=[
                           'Country', 'Affected_KM', 'Affected_Area'])
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# View data
asia_output.head()
# Out:
#   Country  Affected_KM  Affected_Area
# 0     AFG          3.0            0.0
# 1     ARM          0.0            0.0
# 2     AZE          0.0            0.0
# 3     BHR          0.0            0.0
# 4     BGD         26.0            0.0

# %%
# Remove rows that have 0 values for rivers. 
asia_affected = asia_output[asia_output.Affected_KM != 0]
asia_affected = asia_output[asia_output.Affected_Area != 0]

asia_affected.head()
# Out:
#    Country  Affected_KM  Affected_Area
# 7      KHM        218.0           27.0
# 8      CHN        227.0      5604618.0
# 12     IND        773.0       270143.0
# 17     JPN         38.0            1.0
# 21     KOR         29.0            1.0

# %%
# Export to csv.
affected_path = os.path.join(wd_path, "asia_affected.csv" )
asia_affected.to_csv(affected_path)

# %%
# Create Graph
# use white grid plot background from seaborn
sns.set(font_scale=1.5, style='whitegrid')

fig, ax = plt.subplots(figsize=(20, 10))
ax.bar(asia_affected["Country"],
        asia_affected["Affected_KM"], color='blue', label="River Length")
plt.legend(loc="upper rigth")
ax.set(title="Length of Potential River Reaches impacted by Future Dam Construction\nAsia",
       xlabel="Country", ylabel="Kilometers")
ax.text(0.5, -0.1,
        "Data Source: Free Flowing Rivers Database",
        size=12,
        ha="center",
        transform=ax.transAxes)
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Unrecognized location 'upper rigth'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# Text(0.5, -0.1, 'Data Source: Free Flowing Rivers Database')

# %%
# Create Graph
# use white grid plot background from seaborn
sns.set(font_scale=1.5, style='whitegrid')

fig, ax = plt.subplots(figsize=(20, 10))
ax.bar(asia_affected["Country"],
        asia_affected["Affected_Area"], color='orange', label="Land Area")
plt.legend(loc="upper rigth")
ax.set(title="Potential Protected Areas impacted by Future Dam Construction\nAsia",
       xlabel="Country", ylabel="Square Meters")
ax.set_yscale("log")
ax.text(0.5, -0.1,
        "Data Source: World Database of Protected Areas and Ramsar Site Database",
        size=12,
        ha="center",
        transform=ax.transAxes)
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Unrecognized location 'upper rigth'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# Text(0.5, -0.1, 'Data Source: World Database of Protected Areas and Ramsar Site Database')

# %%
# Turn asia dams from point to poly by buffering so that overlay function works
dams_all = dams_all.set_geometry('geometry').to_crs('epsg:4087')
dams_all['geometry'] = dams_all.buffer(50000)
              
# Overlay proposed dams on protected areas for selected continent to get ONLY dams that overlap PAs
asia_dams = gpd.overlay(
    dams_all, wdpa_ramsar_asia, how='intersection')

# Overlay  protected areas on proposed dams for selected continent to get ONLY pas with dams
asia_pas_affected = gpd.overlay(
    wdpa_ramsar_asia, dams_all, how='intersection')
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
# Drop rows with NaN values
asia_pas_affected = asia_pas_affected[['NAME', 'PARENT_ISO', 'Shape_Area','DAM_ID', 'Project na', 'Continent', 'Country', 'Main_river', 'Major Basi', 'Capacity (','LAT_cleane','Lon_Cleane','Stage','Start','End']]
asia_pas_affected.dropna(subset = ['NAME'], inplace=True) 
asia_pas_affected = asia_pas_affected[asia_pas_affected['Continent'] == "Asia"]
asia_pas_affected.drop_duplicates(subset=['NAME', 'Project na'], keep='first', inplace=True)
asia_pas_affected.columns = ['Protected_Area_Name', 'Country_ISO', 'Area_of_Protected_Area','Dam_ID', 'Dam_Project_Name', 'Continent', 'Country', 'Main_River', 'Major_Basin', 'Dam Capacity','Dam_Latitude','Dam_Longitude','Dam_Stage','Dam_StartDate','Dam_EndDate']
# Out:
# C:\Users\lherwehe\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Export to csv.
asia_pas_dams_path = os.path.join(wd_path, "asia_pas_dams_affected_50km.csv" )
asia_pas_affected.to_csv(asia_pas_dams_path)

# %%
# # Get clean list of all PAs affected and all dams that overlap PAs
# asia_pas = unique(asia_pas_affected['NAME'])
# asia_pas = pd.DataFrame(asia_pas) 
# asia_dams = unique(asia_dams['Project na'])
# asia_dams = pd.DataFrame(asia_dams) 

# # Export to csv.
# affected_dams_path = os.path.join(wd_path, "asia_dams_affected.csv" )
# asia_dams.to_csv(affected_dams_path)

# # Export to csv.
# affected_pas_path = os.path.join(wd_path, "asia_pas_affected.csv" )
# asia_pas.to_csv(affected_pas_path)
# Out:
# nan
# Lake Arpi
# Gangtey-Phobji
# Hubei Dajiu Lake Wetland
# Lashihai Wetland
# Keshopur-Miani Community Reserve
# Beas Conservation Reserve
# Lower Songkhram River
# Lake Cluster of Pokhara Valley
# Lake Seyfe
# Sultan Marshes
# Dashanbao
# Göksu Delta
# Nemrut Caldera
# Yumurtalik Lagoons
# Lake Uluabat
# Lake Kus
# Lentekhi
# Tvishi
# Zhoneti
# Namakhvani
# Dzegvi
# Khumpreri
# Lekarde
# Magana
# Khudoni
# Paravani Hepp
# Tundsha
# Baram
# Limbang
# Baleh
# Lawas
# Hulu Terengganu
# Myitsone
# Pashe
# Lakin
# Phizaw
# Kaunglanphu
# Laiza
# Chibwe
# Chibwe Creek
# Tarpein I
# Tarpein Ii
# Nam Myaw
# Shweli Ii
# Shweli Iii
# Upper Thanlwin-
# Tasang
# Kengtawng
# Kyaukme
# Buywa
# Nancho
# Tamanthi
# Sai Din
# Shwesayay
# Taninthayi
# Weigyi
# Dagwin
# Hat Gyi
# Songta
# Cuole
# Erdaogou
# Linhai
# Shilong(Songjaing Cascade)
# Laolongkou
# Huma
# Nen
# Fabiela
# Nuomin
# Yichun-Wuma
# Mudan
# Fuer
# Erdao
# Giluy
# Selemdzha
# Second Songhua
# Zhanhe
# Isawa
# Jobarugawa
# Tsugaru
# Yubarisyuparo
# Long Xi Kou
# Qian Wei
# Sha Zui
# Sha Ba
# An Gu
# Fa Hua Si
# Zhen Tou Ba
# Lao Ying Yan
# Ying Liang Bao
# Huang Jin Ping
# Dan Ba
# Ba Di
# Jin Chuan
# Shuang Jiang Kou
# Bu Si Gou
# Da Wei
# Ba La
# Xia Er Jia
# Changheba
# Dagangshan
# Houziyan
# Sichuan Shuoquhe Quxue
# Lai Chau
# Nuoc Trong
# Huoi Quang
# Song Bung 4
# Song Bung 2
# Huong Dien
# Dak D'Rinh
# Thuong Kon Tum
# Prek Liang 1
# Sambor
# Stung Treng
# Lower Se San 2
# Lat Sua
# Nuozhadu
# Pak Beng
# Luang Prabang
# Xayabouri
# Pak Lay
# Sanakham
# Pak Chom
# Ban Koum
# Don Sahong
# Mengsong
# Gongguoqiao
# Lidi
# Thakho
# Ganlanba
# Huangdeng
# Tuoba
# Wunonglong
# Nam Tha
# Nam Ngum 3
# Nam Khan 2
# Nam Khan 3
# Xekaman 1
# Nam Kong 1
# Jatigede
# Upper Cisokan
# Allain Duhangan
# Bhaironghati I
# Bhaironghati Ii
# Bhilangana I
# Bhilangana Ii
# Gangotri
# Harsil
# Jadhganga
# Karmoli
# Lotharinag Pala
# Koteshwar
# Kotli Bhel Ia
# Pala Maneri I
# Alaknanda
# Bagoli
# Bowla Nandprayag
# Chuni Semi
# Shrinagar
# Deodi
# Devsari
# Gaurikund
# Gohana Tal
# Jelam Tamak
# Karnaprayag
# Lakshmanganga
# Lata Tapovan
# Maleri Jelam
# Nandprayag Langasu
# Padli
# Phata-Byung
# Rambara
# Rishiganga I
# Rishiganga Ii
# Tamak Lata
# Urgam-Ii
# Utyasu
# Vishnugad Pipalkoti
# Arakot Tiuni
# Barkot Kuwa
# Chirgaon Majhgaon
# Damta Naingaon
# Dhamwari Sunda
# Hanol Tiuni
# Hanuman Chatti
# Jakhol Sankhri
# Kishau
# Lakhwar
# Mori Hanol
# Naitwar Mori
# Paudital Lassa
# Renuka
# Rupin
# Rupin Iii.Iv.V
# Taluka Sankhri
# Tangnu Romai
# Tiuni Plasu
# Tipaimukh
# Vyasi
# Puwa-Jhutre
# Jogmai Khola
# Madi-Bhorletar
# Siddhi Khola
# Khorunga Khola
# Middle Modi
# Bagmati Nadi
# Uppper Solu Khola Small
# Suti Khola
# Tugun Khola
# Khani Khola
# Middle Super Daraudi
# Upper Daraundi
# Middle Gaddi Gad
# Upper Panpu Khola
# Chepe Khola
# Rupse Khola
# Uppper Khimti Ii
# Madi Khola
# Ghalemdi Khola
# Tallo Bagmati
# Sabha Khola A
# Panagad Khola
# Poldumki Khola
# Siwan Khola
# Roshi Khola & Ladku Khola
# Tanchhahara Small
# Mai Khola B
# Yandeli Khola
# Roshi Khola
# Daraundi-1
# Rigdi Khola
# Ruru Banchu - 1
# Ruru Banchu Khola- 2
# Taman Khola
# Upper Gaddi Gad
# Upper Molun
# Rudi A
# Upper Bagmati
# Lower Chameliya
# Nyam Nyam
# Lower Khorunga
# Lower Jogmai Khola
# Upper Chingad
# Badigad (Kolti)
# Nisi Khola
# Sudha Khola
# Sawane -A
# Badigad -A
# Ghatte Khola
# Middle Midim
# Lawa Khola
# Chandravati Khola
# Manahari Khola
# Trishuli Khola
# Lower Igwa Khola
# Upper Myagdi
# Chhaldi Khola
# Middle Sunkoshi
# Bhuji Khola
# Middle Tadi
# Lower Balephi-3
# Balephi A
# Theule Khola
# Sabha A
# Upper Badigad
# Ghar Khola
# Hewa Khola 'A'
# Lower Pheme Khola
# Yambaling Khola
# Kalanga
# Sanigad
# Bagar Khola
# Rapti Khola
# Devighat Cascade Hpp
# Katti Khola
# Lower Phalaku Hpp
# Upper Chepe Hpp
# Upper Naugad
# Rukum Gad
# Super Chepe
# Suri Khola
# Mudi Khola
# Salankhu Khola
# Makari Gad
# Mah Khola
# Upper Maya Khola
# Daram Khola-A
# Nimrung Khola
# Banganga
# Indrawati Melamchi
# Likhu A Hpp
# Iwa Khola
# Upper Jogmai Hpp
# Lahu Khola
# Chulepu Khola
# Seti Khola Hpp
# Pa Khola
# Upper Hewa Hpp
# Chake Khola Hpp
# Lower Khani Khola Hpp
# Nisi Khola Hep-1
# Thadekhani Khola Hpp
# Upper Khoranga Khola Hpp
# Badigad Hpp
# Phalakhu Khola Hpp
# Upper Indrawati
# Lower Chirkhuwa
# Lohare Khola
# Phenlun Briddhin Diversion Hpp
# Jhyaku Khola
# Sisa Khola Hpp
# Kapadigad
# Parajuli Khola-1
# Tame Khola Shp
# Malagad
# Upper Piluwa Khola-2 Shp
# Liping Khola
# Upper Katti Khola Hpp
# Taman Khola Hep-1
# Lower Modi-Ii Cascade Hpp
# Lower Lohore Khola Hpp
# Bijaypur Khola-2 Hpp
# Chake Khola
# Upper Charnawati Khola
# Taman Khola Hep-2
# Jhon Khola Hpp
# Dudh Khola Hpp
# Upper Mardi Hydropower Project
# Upper Chirkuwa Khola
# Hewa Khola - B
# Orang Khoa Hpp
# Mai Cascade Hpp
# Bauligad Khola Hpp
# Istul Khola Hpp
# Phakphok Khola Hpp
# Taksar Pikuwa
# Saptang Khola Hpp
# Pikhuwa Khola ( Khawa ) Hpp
# Kailash Khola Hpp
# Madkyu Khola
# Sardi Khola
# Chauri Khola
# Roshi Mangaltar Hpp
# Sisa Khola A Hydropower Project
# Molun Khola Shp
# Upper Syange Khola Shp
# Dwari Khola Shp
# Upper Modi Hpp
# Rawa Khola Hpp
# Super Lohare Khola Hpp
# Sabha Khola-B Hpp
# Rele Khola
# Irkhuwa Khola-B Hpp
# Middle Daram Khola-A Hpp
# Middle Daram Khola-B Hpp
# Aan Balephi B
# Lower Irkhuwa Khola
# Lower Selang Khola
# Kasuwa Khola Hpp
# Tadi Khola Cascade
# Upper Dordi A Hep
# Kwaligau Khola
# Middle Tara Khola Shp
# Bojyan Khola
# Middle Bhotekoshi -1
# Chameliya (Chhetigad)
# Middle Tamor
# Sankhuwa Khola
# Mathillo Aankhu Khola
# Lower Likhu
# Upper Rahughat
# Upper Khudi
# Upper Madi - 0
# Trishuli Galchhi
# Myardi Khola
# Nilgiri Khola
# Super Dordi Kha Hydropower Project
# Likhu Khola 'A'
# Upper Balephi A
# Lower Tamor
# Seti Nadi Hep
# Rahughat Mangale
# Beni Kaligandaki
# Tamakoshi -1
# Marsyangdi Besi
# Jagadulla Khola
# Chhati Gad
# Upper Sankuwa Khola
# Solu Khola (Dudha Koshi)
# Nar Khola
# Kirne Hydropower Project
# Upper Kalangad
# Kaligandaki Upper
# Thulibheri
# Madi Seti
# Durbang Myagdi Khola
# Nyasim Khola
# Myagdi Khola
# Sanjen Khola
# Super Trishuli
# Deumai Khola
# Seti Nadi-3 Hpp
# Upper Lapche Khola
# Rasuwa Bhotekoshi
# Middle Trishuli Ganga Nadi
# Tamakoshi-V
# Bajhang Upper Seti Hydropower Project
# Myagdi- 2
# Ghandruk Modi
# Manungdanda Solar Power Station
# Lower Bheri Hydropower Projec T
# Tamor Mewa
# Upper Karnali
# Kali Gandaki-Kowan
# Manang Marsyangdi
# Budhi Gandaki Ka
# Budhi Gandaki Kha
# Arun 3
# Upper Marsyangdi 1
# Tila-1 Hydropower Project
# Tila-2 Hydropower Project
# Lower Manang Marsyangdi
# Phulkot Karnali
# Seti
# Namlan
# Lapche Khola
# Chainpur Seti Hep
# Dudhkoshi-2 (Jaleswar) Hpp
# Dudhkoshi-4(Taksindu) Hpp
# Upper Trishui-2 Hpp
# Karnali -7
# Mugu Karnali-1
# Humla Karnali-1
# Thuli Bheri
# Bheri-1 Hydropower Project
# Bheri-2 Hydropower Project
# Bheri-3 Hydropower Project
# Budhi Gandaki Storage Hydropower Project
# Madhya Bhotekoshi
# Nalsyaugad
# Budhigandaki Hydropower Project
# Thuli Bheri-1 Hpp
# Bheri-3 Storage Hydropower Project (Br-3)
# Mailung Khola
# Lower Indrawati
# Chameliya Khola
# Kule Khani Third
# Lower Chaku Khola
# Sipring Khola
# Lower Modi -1
# Siuri Khola
# Ankhu Khola - 1
# Upper Madi
# Upper Mai Hydropower Project
# Mai
# Lower Modi Khola
# Phawa Khola Hydropower Project
# Charnawati Khola Hydroelectric Project
# Upper Tamakoshi Hpp
# Upper Trishuli 3A
# Jiri Khola Shp
# Pikhuwa Khola
# Middle Chaku Khola
# Khani Khola - 1
# Radhi Small
# Dordi Khola
# Rahughat
# Lower Balephi
# Tadi Khola
# Jumdi Khola Small
# Mistri Khola
# Tadi Khola (Thaprek)
# Sanjen
# Upper Mailung -A
# Third Trishuli Nadi
# Upper Chaku A
# Likhu-4
# Upper Marsyangdi A
# Thapa Khola
# Daraundi A
# Jhyari Khola
# Lower Khare
# Naugadh Gad
# Chhahare Khola
# Upper Hugdi
# Midim Khola
# Upper Sanjen
# Kabeli-A Hydropower Project
# Bhasme
# Bimkyong
# Bop
# Chhakung Chhu
# Chuzachen
# Dik Chhu
# Jorethang Loop
# Lachen
# Lachung
# Lingza
# Panan
# Ralang
# Rammam I. Iv
# Rangit Ii. Vi
# Rangyong
# Ringpi
# Rongni
# Rukel
# Sada Mangder
# Suntaley Tar
# Talem
# Tashiding
# Teesta I
# Teesta Ii
# Teesta Iii
# Teesta Iv
# Teesta Vi
# Ting Ting
# Kameng
# Pakal Dul
# Pare
# Subansiri Lower
# Nyamjang Chhu
# Punatsangchhu I
# Punatsangchhu Ii
# Mandaniganga
# Liyang
# Qinglong
# Duonuo
# Baihetan
# Xiang Jia Ba
# Xi Luo Du
# Wu Dong De
# Yin Jiang
# Jin Sha
# Liang Jia Ren
# Long Pan (Upper Tiger Leaping)
# Ben Zi Lan
# Ri Mian
# Chang Bo
# Su Wa Long
# Ba Tang
# La Wa
# Ye Ba Tan (Yeba Rapids)
# Bo Luo
# Yan Bi
# Gang Tuo
# Guo Tong
# Tong Zi Lin
# Jin Ping I
# Jin Ping Ii
# Ka La
# Yang Fang Gou
# Meng Di Gou
# Leng Gu
# Ya Gen
# Liang He Kou
# Gong Ba Gou
# Gong Ke
# Xin Long
# Ying Da
# Tong Ha
# Ge Ni
# A Da
# Re Ba
# Ren Qing Ling
# Wen Bo Si
# Xiao Nan Hai
# Guanyinyan
# Ludila
# Longkaikou
# Liyuan
# Upper Tiger Leaping Gorge
# Tingzikou
# Xun Yang
# Pan Kou
# Longbeiwan
# Shiziping
# Lizhou
# Mamaya No 1
# Madushan
# Kushitayi
# Dengke
# Wenquan
# Baopinghe
# Hunan Huitong Gaoyi
# Hubei Loushui Jiangpinghe
# Pangduo
# Baishi
# Qingyanggou
# Xinjiang Kumalake Xiaoshixia
# Yamuhe
# Agus 3
# Bulanog Batang
# Diamer-Bhasha
# Dasu Hydropower Project
# Bunji Hydropower Project
# Keyal Khwar
# Kurram Tangi
# Munda
# Akhori
# Lower Palas Valley
# Lower Spat Gah
# Basho Hydropower Project
# Phandar Hydropower Project
# Thakot Hydropower Project
# Patan Hydropower Project
# Neelum?Jhelum Hydropower Plant
# Golen Gol Project
# Patrind
# New Bong Escape
# Kalabagh
# Harpo
# Mahl Hydropower Project
# Kotli Hydropower Project
# Guddu
# Karot. Pakistan
# Azad Pattan
# Harighel
# Sehra
# Chakotti Hattian
# Jagran-Ii
# Jabban
# Sharmai
# Madian. Pakistan
# Asrit Ke
# Kalam Asrit
# Gabral Kalam
# Karang
# Shogo-Sin
# Naltar-3
# Naltar-5
# Yulbo Hydropower Project
# Shyok Hydropower Project
# Tungus Hydropower Project
# Skurdo
# Dudhnial Hydropower Project
# Suki Kinari Hydropower Project
# Kundal Shahi Hydropower Project
# Trappi Hydropower Project
# Rajdhani Hydropower Project
# Tangir Hydropower Project
# Matiltan Hydropower Project
# Gulpur Hydropower Project
# Naulong
# Hingol
# Daraban Zam
# Tank Zam
# Bara
# Ghabir
# Papin
# Lara Sumta
# Luhri
# Mane Nadang
# Poo Spiloo
# Ropa
# Sumta Kathang
# Thopan Poweri
# Tidong Ii
# Yangthang Khab
# Karcham Wangtoo
# Kashang I
# Kashang Ii & Iii
# Kashang Iv
# Kol
# Rampur
# Shongtong Karchan
# Sorang
# Tidong I
# Ilisu
# Main Cetin
# Lower Cetin
# Boyabat
# Alpaslan2
# Gerze
# Tasoba
# Gokcebel
# Dilektasi (I)
# Kavaktepe
# Denizgolu
# Guneyce
# Arkun
# Cetin
# Kavsak-Bendi
# Sarigüzel
#  Cizre***
#  Be?kari?
#  Imranli
#  Ki?i
#  Ba?köy
#  Köprüba?i
#  Çokal
#  Ta?oluk
#  Güzelce
#  Ba?lik***
#  Laleli***
#  Akköy
#  Boztepe
#  Yusufeli***
#  Artvin***
#  Narli
#  Gökbel
#  Bozkir
#  Mut***
#  Köprü
#  Mavi
#  Gökta?
#  Alaköprü
#  Imamo?lu
#  Çermikler
#  Söylemez
#  Ay?ehatun
#  Güzeldere
#  Çay
#  Elmali
#  Aladereçam
#  Tirebolu
#  Karya?maz
#  Silvan
#  Sirimta?
#  ?irvan
#  Kasimlar
#  Pamukluk
#  E?lence
#  Kepezkaya
#  Kocali
#  Efrenk
#  B.Karaçay
#  Kami?li
#  Kirkemir
#  Hakkari***
#  Dilekta?i
#  Çukurca***
#  Kizilsu
#  Hezil
#  Ba?kale
#  Eruh
#  Karasu
#  Orhaneli
#  Çavu?lu
#  Çatalbahçe
#  De?irmendere
#  Akyayik
#  Dipni
#  Kemah
#  Eriç***
#  Büyükçay
#  Garzan
#  Kor
#  Baykan
#  Kaleköy***
#  Findikli
#  Kazan
#  Kizila?aç
#  Balaban
#  Cide
#  Kovanlik
#  Ören
#  Ortaköy
#  Suçati
#  Tor
#  Ikisu
#  Koru
#  Tozköy
#  Kulo?lu
#  Karakurt
#  Kuleta?i
#  So?ukpinar
#  Koçlu
#  Akçakale
#  Çataloluk
#  Cürümören
#  Kartal
#  Kozbükü
#  Çileklitepe
#  Göcen
#  Durak***
# Kandil
# Morgedik
# Aydintepe
#  A?a?ikörkün
#  Lapinar
#  Gümü?ören
#  Zeytinli
#  Kaynarca
#  Beyhani***
#  Be?konak
#  Güllüba?
#  Ta?köprü
#  Pülümür
#  Bayram***
#  Arma?an
# Yoncali Reg. Ve
# Sö?ütlü Reg. Ve
#  Gökçesih
#  B.Melen
#  Susurluk Çayi
#  Sabolu Baraji Ve
#  Gündo?mu?
#  ?ahinkaya
#  Bayramhacili
#  Samisoy-Sandalcik
#  Çamba?i Baraji Ve
#  Kovanlikdere (Linlin I-Ii-Iii)
#  Ardiçli
#  Kayraktepe
#  Arkun
#  Ispir (Bademli)
#  Ispir (Çatakbahçe)
#  Tortum-Ii
#  Konaktepei-Ii
#  Pervari
#  Alara
#  Sinanhoca
#  Üzümdere
#  Alpaslan-Ii
#  Ba?i?li
#  Altiparmak
#  Ayvadere
#  Çankaya Baraji Ve
#  Çiraki
#  Dikkaya
#  Erenler (Çoruh)
#  Ö?dem Reg. Ve
#  Uzungölof-Solakli
#  Yuk. Manahoz R.Ve
#  Demirkapi
#  Kaleba?i
#  Kotanli
#  Tuzluca
#  Kizkayasi
#  Kadincik-Iii
#  Kadincik-Iv
#  Ba?i?ta?
#  Ba?i?ta? Ii
#  Sansa
#  Do?anli***
#  Ba?ak
#  Gürpinar
#  Ikizkavak
#  Akta? Baraji Ve
#  Ilica
#  Ardanuç-I
#  Gökta?-Eie
#  Balkusan
#  Gökdere Reg. Ve
#  Asmaca
#  Kami?li 2
#  Sarikavak Bar. Ve
#  Ayancik
#  Aksu (Yankol)
#  Bayraktar
#  Çaya?an
#  Özlüce (Çoruh)
#  Sarikonak
#  Tortumkale-I
#  Kesikköprü(Firat)
#  Palu
#  Yaziköy
#  Çetin***
#  Oran
#  Manavgat-1
#  Manavgat-2
#  Zincirli
#  Akçay I
#  Akçay Ii
#  Ulubey
#  Angutlu
#  Avluca
#  Güneyce Bar. Ve
#  Serpin
#  Ya?lidere
#  Kaya Baraji
#  Arpaçay
#  Emet
# Asarcik
# Ketir
# Uzungöl-1-Reg. Ve
# Göçen Reg. Ve
# Firnis Reg. Ve
# Pervari Reg. Ve
# Meydancik Reg. Ve
#  Boyabat-Kepez
#  Yenicekent
#  Pazarköy
#  Bucakki?la
#  Aksu(Düzce)
#  Karakuz Bar. Ve
#  Pembelik
#  Aslancik
#  Yamanli-Ii
#  Yamanli-Iii
#  Akinci
#  Darica-Ii
#  Bolaman
#  Kav?ak
#  Tuzkoy
# ?emdinli Baraji Ve
#  Bucakköy
#  Burgular-Gebe?
#  Firnis
#  Erenler
#  Çukurkaya
#  Sadikli
#  Hakkari-Geçitli
#  Çitakli
#  Kardakli
#  Ortaköy-Foldere
#  Akçay
#  Akçay 1
#  Akçay 2
#  Gök
#  Güvercinlik
#  Kalinharman
#  Kocayatak
#  Dinç Reg. Ve
#  Gökboyun Reg. Ve
#  A?kolu
#  Dibecik
#  Kayadibi
#  Kaynar Reg. Ve
#  Melet-I
#  Melet-Ii
#  Ortakoy
#  Oskara
#  Piro
#  Tekatan
#  Tortumkale-Ii
#  Ilica(Firat)
#  Alakir-1
#  Alakir-2
#  Balir
#  Çandir-1
#  Çandir-2
#  Çandir-3
#  O?uz
#  Sapa
#  Yaylabel
#  Ömerlerdüzü
#  Avcilar
#  Kizilça?il
#  Namnam
#  Sarikavak
#  Akhisar
#  A?iklar
#  Ballica
#  Batlama Reg.
#  Bibat (Derive)
#  Büyük Reg. Ve
#  Cinali
#  Çatalçam
#  Dumankaya
#  Holo
#  Horyan
#  Iftelan
#  Kadiralak
#  Kahraman
#  Kiran
#  Kizilev
#  Koyunhamza
#  Kutulu
#  Küçükdere
#  Manahoz
#  Ortaça?
#  Selimo?lu
#  Seydio?lu
#  Solakli
#  Tokmadin
#  Turhan Reg. Ve
#  Vanazit
#  Zekere
#  De?irmenönü
#  E?erci Reg. Ve
#  Kizilçam
#  Kuzköy Reg. Ve
#  Örenalti
# Sisne
# Ardanuç Reg. Ve Ges
# Horu
# Zinav Reg. Ve
# Do?an?ar Reg. Ve
# Poyrazli Reg. Ve
# Gemin Reg. Ve
# Kadahor Reg. Ve
# Alada? Reg. Ve
# Kozgedi?i Reg. Ve
# Ba?köy Reg. Ve
# Hasanabdal Reg. Ve
# Aydin Reg. Ve
# Yassita? Reg. Ve
# Yarpuz Reg. Ve
# Tapsur Reg. Ve
# Selköy Reg. Ve
# Ahlar Reg. Ve
# Erdeviz Reg. Ve
# Dibekkaya Reg. Ve
# Tünke? Reg. Ve
# Üçta? Reg. Ve
# Göngele Reg. Ve
# Kocaklar Reg. Ve
# Larhan Reg. Ve
# Karaçay Reg. Ve
# Çayirözü Reg. Ve
# Sorgun Reg. Ve
# Sazak
# Sivrita? Reg. Ve
# Ifletan Reg. Ve
# Çanakci Reg. Ve
#  Timarli
#  Esendurak
#  Rüzgarli Reg. Ve
#  Avanos-Cemel
# Bakhtiyari
# Gotv Oliya
# Khersan 3
# Shahryar
# Nargesi
# Mirza Ye Shirazi
# Sardasht
# Tupolang
# Rogun
# Kambaratinsk
# Lawi
# Kohala Hydropower Project
# Bardang
# Bursar
# Chattru
# Dugar
# Gondhala
# Gyspa
# Khoksar
# Miyar
# Patam
# Rashil
# Ratle
# Reoli Dugli
# Sach Khas
# Seli
# Tandi
# Teling
# Tinget
# Baglihar Ii
# Uhl Iii
# Parbati Ii
# Parbati Iii
# Sainj
# West Seti
# Mangdechhu
# Sankosh
# Kuri-Gongri
# Amochhu
# Kholongchhu
# Chamkharchhu-I
# Wangchhu
# Bunakha
# Nikachhu
# Khomachhu
# Rotpashong
# Gamri
# Zangmu
# Battambang 1
# Battambang 2
# Pursat 1
# Pursat 2
# Lower Se San 3
# Prek Liang 2
# Lower Sre Pok 3
# Lower Sre Pok 4
# Stung Sen
# Nam Theun1
# Namngiep 1
# Nam Ngiep-Regulating Dam
# Xepian-Xenamnoy
# Xe Katam
# Xekong 4
# Xe Kong 3Up
# Xe Kong 3D
# Xe Kong 5
# Nam Ou 1
# Nam Ou 2
# Nam Ou 3
# Nam Ou 4
# Nam Ou 5
# Nam Ou 6
# Nam Ou 7
# Nam Lik 1
# Nam San 3
# Nam Pha
# Nam Suang 1
# Nam Suang 2
# Nam Nga
# Nam Beng
# Nam Feuang 1
# Nam Feuang 2
# Nam Feuang 3
# Xe Pon 3
# Xe Kaman 2A
# Xe Kaman 2B
# Xe Kaman 4A
# Xe Kaman 4B
# Dak E Mule
# Nam Khan 1
# Nam Ngum 4A
# Nam Ngum 4B
# Nam Ngum, Lower Dam
# Nam Pay
# Nam Mang 1
# Nam Pouy
# Nam Poun
# Nam Ngao
# Nam Chian
# Nam Ngieu
# Nam Pot
# Nam San 3B
# Nam San 2
# Nam Pok
# Nam Hinboun 1
# Nam Hinboun 2
# Xe Bang Fai
# Xe Neua
# Nam Theun 4
# Nam Mouan
# Xe Bang Hieng 2
# Xedon 2
# Xe Set 3
# Xe Bang Nouan
# Xe Lanong 1
# Xe Lanong 2
# Xe Nam Noy 5
# Houay Lamphan
# Nam Kong 2
# Xe Xou
# Duc Xuyen
# Shah Wa Arus
# Kuran Wa Murjan
# Yamgan
# Khau Chu 1
# Khau Chu 2
# Chathankottunada Stage-Ii
# Chathankottunada Stage-Ii (2Nd Dam)
# Beedalli
# Sao Va
# Nam Cau 2
# Youyang Xishakou
# Panoth
# Valuk
# Hedcor Tudaya 1
# Hedcor Tudaya 1B
# Youyang Xiaoxianjing
# Dak Glun 2 And 3
# Kirkoswald
# Himachal Pradesh 2
# Palor Ii
# Siul-Baroti
# Sidalong 3
# Shidongkou
# Gramang
# Dak Mi 1-1A Sub Dam
# Pao Cu Sang
# Pao Cu Sang Dam 2
# Bixi
# Perunthenaruvi
# Thien Nam 3
# Song Cho 2 Hydro Power
# Dak Glun 3
# Dak Pring
# Yiliang Baishuijiang Wenjiao
# Dong Ngai
# Tudaya 2
# Orissa
# Desang
# Dah
# Hanu
# B?Ri 1
# Axia Nagai
# Jeori
# Nam Xa
# Skhalta
# Toudaoqiao
# Tarabintang
# Tunggang
# Dak Srong 3A
# Ta Loi 2
# Chu Linh
# Ban Nhung
# Sidalong 2
# Bajiaodiao
# Wentai
# Jongini
# Dangqia
# Nekkiladi
# Niulu
# Thien Nam 1
# Yunnan Tengchong Yongxing
# Uhl Khad
# Nam Sana
# Paekdusan Songun Youth
# Bao Nhai
# Nam Tha 3
# Shangbaishui
# Xinjiang
# Barapole
# Xoong Con
# Nam Si Luong 4
# Guizhou Nayong
# Song Luy
# Mawogou
# Nam Si Luong 3
# Tao River Xiaozuping
# Son Tay
# Yunnan Shuijing
# Tongping
# Wuyang
# Gaozhuoying
# Loushanggou
# Lianghui Tuo
# Guangjinba
# Roura- Ii
# Nam Non
# Nam Can 2
# Langao Donghe Longbanying
# Ganluo Aga
# Yunnan Daping
# Bubunawan 2
# Sansigou
# Sichuan Tongjiang Hongkou
# Jiesigou
# Zhaishang
# Sha?Er
# Hongtu
# Zhenjiangguan
# Heishuihe Ii
# Kukke Stage - 1
# Gullu
# Kanchanjunga
# Ganluo Wagujiao
# Dayuanba
# Bakhshabad
# Baishuijiang Qujiahekou
# Coc San
# Puyo
# Guizhou Jianhe County Chengjing
# Yunnan Diaojiangyan
# Sinan Qilitang
# Vinh Son 3
# Tram Tau
# Moragolla
# Tingminghe
# Mengman
# Nam Toong
# Broadlands
# K?rnati
# Khelvachauri 2
# Qianzhangyan Cascade
# Parnai
# Marjingla Ii
# Chi Khe
# Hasang
# Khelvachauri 1
# Salma
# Nam Ngiep 3A
# Pachuk-Ii
# Nhan Hac
# Bac Me
# La Ngau
# Qinghai Maqin Gequ
# Mianyang
# Xinjiang Ili Kukesu
# Marjingla Lower
# Tsachu-I
# Pakke Bung ? I
# Lower Kalnai
# Song Tranh 4
# Dak Mi 1-1A
# Xinjiang Kaidu
# Shaqian
# Gansu Bazang
# Charikou
# Angsai
# Dak Mi 3
# Semangka
# Luota
# Shangjianpo
# Hanniuhe
# Fubianhe Yangjiawan
# Pachuk Ii
# Jiaoba
# Khertvisi 2
# Khuitam
# Xiangda
# Linchang
# Ya?An City Xi River Chujugou
# Xinjiang Hetian Yulongkashi
# Yunnan Lvzhijiang
# Sichuan Liangshan Yuexi Mantan
# Koromkheti 2
# Koromkheti 3
# Nam Na 3
# Rongge
# Tsachu - Ii
# Tsachu ? I
# Pachuk-1
# New Ganderbal
# Dikchu
# Rongnichu
# Qingsong
# Mianyang Fujiang Main Stream Gucheng
# Yuelong
# Minzhi
# Dariali
# Dongzhong
# Leyi
# Ruyi
# Jinyuan
# Nafra
# Lixin
# Lower Stung Russei Chrum Lower
# Furong River Haokou
# Guangxi Laokou
# Koromkheti 1
# Dong Nai 5
# Cege
# Guoduo
# Dongyi River Yidi
# Khertvisi 1
# Bajoli Holi
# Zhongbo
# Yunnan Puxiqiao
# Reqin
# Lower Stung Russei Chrum Upper
# Shading
# Da?Aguo
# Chengde
# Guangxi Wacun
# Huadian Sichuan Shangtongba
# Kutehr
# Kagong
# Hongdong
# Trung Son
# Shuren
# Xirong
# Shaping Second Stage
# Bitu
# Ulu Jelai
# Shaila
# Kirthai-I
# Fugong
# Yahwei-Urumuka 6
# Xinrong
# Huadian Sichuan Mulihe Kajiwa
# Guizhou Beipanjiang Mamaya 1St Stage
# Upper Marsyangdi-2
# Luohe
# Nujiangqiao
# Zhala
# Kirthai-Ii
# Banda
# Reyu
# Luola
# Bijiang
# Bingzhongluo
# Demwe Lower
# Yabiluo
# Sawalkot
# Yebatan
# Lumadeng
# Xulong
# Rumei
# Guxue
# Longpan
# Maji
# Tongka
# Bangduo
# Gushui

# %%
# Export to csv.
affected_dams_path = os.path.join(wd_path, "asia_dams_affected.csv" )
asia_dams.to_csv(affected_dams_path)

# Export to csv.
affected_pas_path = os.path.join(wd_path, "asia_pas_affected.csv" )
asia_pas_affected.to_csv(affected_pas_path)

pas_with_dams_path = os.path.join(wd_path, "asia_pas_with_dams.csv" )
asia_pas_with_dams = gpd.sjoin(dams_all, wdpa_ramsar_asia, how="inner", op='intersects')
asia_pas_with_dams.to_csv(pas_with_dams_path)

# %%
# Buffer rivers for nicer map
dor_0to5 = dor_0to5.buffer(5000)
dor_5to10 = dor_5to10.buffer(5000)
dor_10to15 = dor_10to15.buffer(5000)
dor_15to20 = dor_15to20.buffer(5000)
dor_over20 = dor_over20.buffer(5000)

# %%
# Get continent dams for plotting
asia_dams = dams_all[dams_all['Continent'] == "Asia"]

asia_dams = asia_dams.to_crs('epsg:4087')

# %%
# Plot all large rivers for selected continent
# Create legend
black_line = mlines.Line2D([], [], color='black', label='Country Border')
blue_line = mlines.Line2D([], [], color='blue', label='0 to 5')
yellow_line = mlines.Line2D([], [], color='yellow', label='5 to 10')
orange_line = mlines.Line2D([], [], color='orange', label='10 to 15')
red_line = mlines.Line2D([], [], color='red', label='15 to 20')
magenta_line = mlines.Line2D([], [], color='magenta', label='20 plus')
lightgreen_patch = mpatches.Patch(color='lightgreen', label='Protected Area')
black_dot = mlines.Line2D([], [], color='white', marker='o',
                          markerfacecolor='gray', label='Proposed Dam Site')

fig, ax = plt.subplots(figsize=(15, 15))
# wdpa_ramsar_asia.plot(ax=ax, color="lightgreen", edgecolor='none')
dor_0to5.plot(ax=ax,
              color='blue', edgecolor='none')
dor_5to10.plot(ax=ax,
               color='yellow', edgecolor='none')
dor_10to15.plot(ax=ax,
                color='orange', edgecolor='none')
dor_15to20.plot(ax=ax,
                color='red', edgecolor='none')
dor_over20.plot(ax=ax,
                color='magenta', edgecolor='none')
asia_dams.plot(ax=ax,
                   color='gray', markersize=50)
ctx.add_basemap(ax, crs='epsg:4087')
ax.set_title(
    'Figure 1: All Protected Areas, Proposed Dams,\n And Large Rivers (Class > 2) by Degree of Regulation in Asia', size = 20)
ax.set_axis_off()
ax.legend(handles = [black_line, blue_line, yellow_line, orange_line, red_line, magenta_line, lightgreen_patch, black_dot],
          fontsize = 15,
          frameon = True,
          loc = ('lower right'),
          title = "LEGEND")
ax.text(0.5, -0.1, "Data Source: World Database of Protected Areas, Ramsar Site Database,\n FhRED Proposed Dams, Free Flowing Rivers", size = 12, ha = "center", transform = ax.transAxes)
# Out:
# Text(0.5, -0.1, 'Data Source: World Database of Protected Areas, Ramsar Site Database,\n FhRED Proposed Dams, Free Flowing Rivers')
